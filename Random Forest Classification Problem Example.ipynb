# %%
# importing all the required libraries

import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_curve, auc

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

# %%
print(cancer.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
data = pd.DataFrame(cancer.data, columns=[cancer.feature_names])
data.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension  ... worst radius worst texture worst perimeter  \
# 0                0.07871  ...        25.38         17.33          184.60
# 1                0.05667  ...        24.99         23.41          158.80
# 2                0.05999  ...        23.57         25.53          152.50
# 3                0.09744  ...        14.91         26.50           98.87
# 4                0.05883  ...        22.54         16.67          152.20
#
#   worst area worst smoothness worst compactness worst concavity  \
# 0     2019.0           0.1622            0.6656          0.7119
# 1     1956.0           0.1238            0.1866          0.2416
# 2     1709.0           0.1444            0.4245          0.4504
# 3      567.7           0.2098            0.8663          0.6869
# 4     1575.0           0.1374            0.2050          0.4000
#
#   worst concave points worst symmetry worst fractal dimension
# 0               0.2654         0.4601                 0.11890
# 1               0.1860         0.2750                 0.08902
# 2               0.2430         0.3613                 0.08758
# 3               0.2575         0.6638                 0.17300
# 4               0.1625         0.2364                 0.07678
#
# [5 rows x 30 columns]

# %%
data = data.assign(target=pd.Series(cancer.target))
data.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension  ... worst texture worst perimeter worst area  \
# 0                0.07871  ...         17.33          184.60     2019.0
# 1                0.05667  ...         23.41          158.80     1956.0
# 2                0.05999  ...         25.53          152.50     1709.0
# 3                0.09744  ...         26.50           98.87      567.7
# 4                0.05883  ...         16.67          152.20     1575.0
#
#   worst smoothness worst compactness worst concavity worst concave points  \
# 0           0.1622            0.6656          0.7119               0.2654
# 1           0.1238            0.1866          0.2416               0.1860
# 2           0.1444            0.4245          0.4504               0.2430
# 3           0.2098            0.8663          0.6869               0.2575
# 4           0.1374            0.2050          0.4000               0.1625
#
#   worst symmetry worst fractal dimension target
# 0         0.4601                 0.11890      0
# 1         0.2750                 0.08902      0
# 2         0.3613                 0.08758      0
# 3         0.6638                 0.17300      0
# 4         0.2364                 0.07678      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (569, 31)

# %%
## Independent features and dependent features
X=data.iloc[:,:-1]  
y=data.iloc[:,-1]

# %%
## train test split 
from sklearn.model_selection import train_test_split

# Split the data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
X_train.shape
# Out:
# (426, 30)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
## Hyperparameter Tunning
param_grid = {
    'n_estimators': [50, 100],
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
#     'bootstrap': [True, False],
#     'class_weight': [None, 'balanced']
}

# %%
# Create the GridSearchCV object
from sklearn.model_selection import GridSearchCV

# make a GridSearchCV object
grid_search = GridSearchCV(estimator = classifier,
                  param_grid = param_grid,
                  scoring = "accuracy", #sklearn.metrics.SCORERS.keys()
                  cv = 5,
                  verbose = 1)

# Perform hyperparameter tuning on the classifier
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 720 out of 720 | elapsed:  1.2min finished
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [5, 10],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100]},
#              scoring='accuracy', verbose=1)

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}

# %%
print(grid_search.best_score_)
# Out:
# 0.9600547195622434

# %%
df = pd.DataFrame(grid_search.cv_results_)
df = df.sort_values("rank_test_score")
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 79        0.124185      0.009462         0.009662        0.005504
# 111       0.115337      0.006725         0.004540        0.004755
# 54        0.056982      0.011739         0.003776        0.006148
# 117       0.126791      0.013040         0.003374        0.004134
# 109       0.118452      0.017364         0.007268        0.006239
# ..             ...           ...              ...             ...
# 32        0.054268      0.007990         0.004856        0.005953
# 66        0.055744      0.008455         0.000818        0.001170
# 70        0.053399      0.007371         0.006201        0.004330
# 10        0.063233      0.015520         0.005585        0.006921
# 33        0.108360      0.008748         0.009633        0.005999
#
#     param_criterion param_max_depth param_max_features param_min_samples_leaf  \
# 79          entropy               5               auto                      2
# 111         entropy              10               auto                      1
# 54             gini              10               sqrt                      1
# 117         entropy              10               auto                      2
# 109         entropy              10               auto                      1
# ..              ...             ...                ...                    ...
# 32             gini               5               sqrt                      4
# 66             gini              10               sqrt                      4
# 70             gini              10               sqrt                      4
# 10             gini               5               auto                      2
# 33             gini               5               sqrt                      4
#
#     param_min_samples_split param_n_estimators  \
# 79                        2                100
# 111                       5                100
# 54                        2                 50
# 117                       5                100
# 109                       2                100
# ..                      ...                ...
# 32                        5                 50
# 66                        2                 50
# 70                       10                 50
# 10                       10                 50
# 33                        5                100
#
#                                                 params  split0_test_score  \
# 79   {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.976744
# 111  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.988372
# 54   {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.976744
# 117  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.988372
# 109  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.988372
# ..                                                 ...                ...
# 32   {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.976744
# 66   {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.976744
# 70   {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.976744
# 10   {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.976744
# 33   {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.976744
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 79            0.952941           0.952941           0.988235
# 111           0.929412           0.952941           0.988235
# 54            0.941176           0.964706           0.988235
# 117           0.929412           0.952941           0.976471
# 109           0.941176           0.929412           0.988235
# ..                 ...                ...                ...
# 32            0.894118           0.929412           0.964706
# 66            0.894118           0.917647           0.976471
# 70            0.917647           0.894118           0.964706
# 10            0.905882           0.905882           0.964706
# 33            0.894118           0.917647           0.964706
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 79            0.929412         0.960055        0.020557                1
# 111           0.941176         0.960027        0.024257                2
# 54            0.917647         0.957702        0.025383                3
# 117           0.941176         0.957674        0.021859                4
# 109           0.941176         0.957674        0.025375                4
# ..                 ...              ...             ...              ...
# 32            0.905882         0.934172        0.032162              140
# 66            0.905882         0.934172        0.035438              140
# 70            0.917647         0.934172        0.031290              140
# 10            0.905882         0.931819        0.031994              143
# 33            0.905882         0.931819        0.032847              143
#
# [144 rows x 19 columns]

# %%
##prediction
y_pred=grid_search.predict(X_test)

# %%
## accuracy score
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.972027972027972

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        53
#            1       0.99      0.97      0.98        90
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143
